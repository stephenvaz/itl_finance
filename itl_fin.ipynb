# %%
import pandas as pd
import requests

# %%
url = "https://text-analysis12.p.rapidapi.com/sentiment-analysis/api/v1.1"

# %%
headers = {
	"content-type": "application/json",
	"X-RapidAPI-Key": "902244c5f6mshf1eaa2464e9100fp1993dfjsn610632dea406",
	"X-RapidAPI-Host": "text-analysis12.p.rapidapi.com"
}

# %%
df = pd.read_csv('article.csv')
df.head()
# Out:
#                                                title  \
# 0  Share market update: Most active stocks of the...
# 1  RIL shares jump 2% post Q2 earnings despite Mo...
# 2  Buy Reliance Industries, target price Rs 2760:...
# 3  Hot Stocks: Brokerage view on RIL, Cipla, Maru...
# 4  Stocks in news: RIL, Adani Green, IDFC First B...
#
#                        date                                               info
# 0  30 Oct 2023, 11:25AM IST  The NSE Nifty index was trading 49.5 points up...
# 1  30 Oct 2023, 10:16AM IST  Brokerages reviewed Reliance Industries stock ...
# 2  30 Oct 2023, 09:35AM IST  Reliance Industries Ltd. key Products/Revenue ...
# 3  30 Oct 2023, 09:26AM IST  The September quarter results were in line wit...
# 4  30 Oct 2023, 07:00AM IST  IDFC First Bank reported consolidated net prof...

# %%
for ind in df.index:
	payload = {
		"language": "english",
		"text": f"{df['title'][ind]}. {df['info'][ind]}"
	}
	
	response = requests.post(url, json=payload, headers=headers)
	response = requests.post(url, json=payload, headers=headers)
	print(response.json())
	break
# Out:
# {'app_version': 'v1.1', 'time_taken': 0.0007269382476806641, 'msg': 'Sentiment Analysis successful', 'ok': True, 'aggregate_sentiment': {'neg': 0.0, 'neu': 0.6995, 'pos': 0.3005, 'compound': 0.5831999999999999}, 'sentiment_list': [{'neg': 0.0, 'neu': 0.612, 'pos': 0.388, 'compound': 0.7645, 'sentence': 'Share market update: Most active stocks of the day in terms of total traded value.'}, {'neg': 0.0, 'neu': 0.787, 'pos': 0.213, 'compound': 0.4019, 'sentence': 'The NSE Nifty index was trading 49.5 points up at 19096.75'}], 'sentiment': 'positive'}

# %%
responses = []

# %%
for ind in df.index:
    payload = {
        "language": "english",
        "text": f"{df['title'][ind]}. {df['info'][ind]}"
    }
    try:
        response = requests.post(url, json=payload, headers=headers)
        # {'app_version': 'v1.1', 'time_taken': 0.0007269382476806641, 'msg': 'Sentiment Analysis successful', 'ok': True, 'aggregate_sentiment': {'neg': 0.0, 'neu': 0.6995, 'pos': 0.3005, 'compound': 0.5831999999999999}, 'sentiment_list': [{'neg': 0.0, 'neu': 0.612, 'pos': 0.388, 'compound': 0.7645, 'sentence': 'Share market update: Most active stocks of the day in terms of total traded value.'}, {'neg': 0.0, 'neu': 0.787, 'pos': 0.213, 'compound': 0.4019, 'sentence': 'The NSE Nifty index was trading 49.5 points up at 19096.75'}], 'sentiment': 'positive'}
        # print(response.json())
        response = response.json()
        # df['sentiment'][ind] = response['sentiment']
        # df['confidence'][ind] = response['confidence']
        # df['positive'][ind]  = response['aggregate_sentiment']['pos']
        # df['negative'][ind]  = response['aggregate_sentiment']['neg']
        # df['neutral'][ind]   = response['aggregate_sentiment']['neu']	
        responses.append(response)
    # except:
    #     continue
    except Exception as e:
        print(e)
        break

# %%
responses
# Out:
# [{'app_version': 'v1.1',
#   'time_taken': 0.0007333755493164062,
#   'msg': 'Sentiment Analysis successful',
#   'ok': True,
#   'aggregate_sentiment': {'neg': 0.0,
#    'neu': 0.6995,
#    'pos': 0.3005,
#    'compound': 0.5831999999999999},
#   'sentiment_list': [{'neg': 0.0,
#     'neu': 0.612,
#     'pos': 0.388,
#     'compound': 0.7645,
#     'sentence': 'Share market update: Most active stocks of the day in terms of total traded value.'},
#    {'neg': 0.0,
#     'neu': 0.787,
#     'pos': 0.213,
#     'compound': 0.4019,
#     'sentence': 'The NSE Nifty index was trading 49.5 points up at 19096.75'}],
#   'sentiment': 'positive'},
#  {'app_version': 'v1.1',
#   'time_taken': 0.0012383460998535156,
#   'msg': 'Sentiment Analysis successful',
#   'ok': True,
#   'aggregate_sentiment': {'neg': 0.0,
#    'neu': 0.9608000000000001,
#    'pos': 0.0392,
#    'compound': 0.059199999999999996},
#   'sentiment_list': [{'neg': 0.0,
#     'neu': 0.804,
#     'pos': 0.196,
#     'compound': 0.296,
#     'sentence': 'RIL shares jump 2% post Q2 earnings despite Monday blues.'},
#    {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'Should you buy?.'},
#    {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'Brokerages reviewed Reliance Industries stock following its September quarter earnings on Friday which were broadly in line with their estimates.'},
#    {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': "While Macquarie upgraded the stock from 'underperform' to 'neutral', Jefferies raised the price target while recommending a buy."},
#    {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'Others which reiterated their buy stance include Nomura, Motilal Oswal and Nuvama.'}],
#   'sentiment': 'neutral'},
#  {'app_version': 'v1.1',
#   'time_taken': 0.0007965564727783203,
#   'msg': 'Sentiment Analysis successful',
#   'ok': True,
#   'aggregate_sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#   'sentiment_list': [{'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'Buy Reliance Industries, target price Rs 2760: Motilal Oswal.'},
#    {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'Reliance Industries Ltd. key Products/Revenue Segments include Petrochemicals, Oil & Gas, Income From Financial Services, Other Services, Others and Income from Retailing for the year ending 31-Mar-2022.'}],
#   'sentiment': 'neutral'},
#  {'app_version': 'v1.1',
#   'time_taken': 0.0007715225219726562,
#   'msg': 'Sentiment Analysis successful',
#   'ok': True,
#   'aggregate_sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#   'sentiment_list': [{'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'Hot Stocks: Brokerage view on RIL, Cipla, Maruti Suzuki and Indian Hotels.'},
#    {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'The September quarter results were in line with estimates.'},
#    {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': "Following RIL's underperformance YTD, it raised the rating to neutral."}],
#   'sentiment': 'neutral'},
#  {'app_version': 'v1.1',
#   'time_taken': 0.0009362697601318359,
#   'msg': 'Sentiment Analysis successful',
#   'ok': True,
#   'aggregate_sentiment': {'neg': 0.0,
#    'neu': 0.9365,
#    'pos': 0.0635,
#    'compound': 0.2202},
#   'sentiment_list': [{'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'Stocks in news: RIL, Adani Green, IDFC First Bank, UltraTech, TVS Motor.'},
#    {'neg': 0.0,
#     'neu': 0.873,
#     'pos': 0.127,
#     'compound': 0.4404,
#     'sentence': 'IDFC First Bank reported consolidated net profit of Rs 747 crore for the quarter ended September, which was up 32% year-on-year.'}],
#   'sentiment': 'neutral'},
#  {'app_version': 'v1.1',
#   'time_taken': 0.0011222362518310547,
#   'msg': 'Sentiment Analysis successful',
#   'ok': True,
#   'aggregate_sentiment': {'neg': 0.051,
#    'neu': 0.8133333333333334,
#    'pos': 0.13566666666666669,
#    'compound': 0.12393333333333334},
#   'sentiment_list': [{'neg': 0.0,
#     'neu': 0.861,
#     'pos': 0.139,
#     'compound': 0.2732,
#     'sentence': 'Sterling & Wilson Renewable Energy liable to cough up Rs 516 crore on payment default.'},
#    {'neg': 0.0,
#     'neu': 0.732,
#     'pos': 0.268,
#     'compound': 0.6705,
#     'sentence': 'The ₹418 crore claim from the original promoter is as per the terms of the indemnity agreement.'},
#    {'neg': 0.153,
#     'neu': 0.847,
#     'pos': 0.0,
#     'compound': -0.5719,
#     'sentence': 'While selling the stake to Reliance Industries, Shapoorji Pallonji Group provided indemnity that it will reimburse net liability arising from past liquidated damages if it exceeds ₹300 crore.'}],
#   'sentiment': 'neutral'},
#  {'app_version': 'v1.1',
#   'time_taken': 0.0011301040649414062,
#   'msg': 'Sentiment Analysis successful',
#   'ok': True,
#   'aggregate_sentiment': {'neg': 0.0,
#    'neu': 0.8656666666666667,
#    'pos': 0.13433333333333333,
#    'compound': 0.3862666666666667},
#   'sentiment_list': [{'neg': 0.0,
#     'neu': 0.756,
#     'pos': 0.244,
#     'compound': 0.4404,
#     'sentence': 'Star India net profit down 31 per cent in FY23.'},
#    {'neg': 0.0,
#     'neu': 0.841,
#     'pos': 0.159,
#     'compound': 0.7184,
#     'sentence': "While the company's operating revenue from TV and digital businesses increased by 6% to ₹19,857 crore, its total income increased by 9% to ₹20,699 crore, making it the largest traditional media and entertainment (M&E) company in the country by revenue."},
#    {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'The American media conglomerate is currently in talks with Reliance Industries (RIL) to sell its India business.'}],
#   'sentiment': 'positive'},
#  {'app_version': 'v1.1',
#   'time_taken': 0.0007631778717041016,
#   'msg': 'Sentiment Analysis successful',
#   'ok': True,
#   'aggregate_sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#   'sentiment_list': [{'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'Breakout Stocks: How should investors trade Shriram Finance, Canara Bank and RIL on Monday?.'},
#    {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'Sectorally, buying was seen in public sector, utilities, power, and realty stocks while some selling was seen in consumer durables, metal, and FMCG stocks.'}],
#   'sentiment': 'neutral'},
#  {'app_version': 'v1.1',
#   'time_taken': 0.0024526119232177734,
#   'msg': 'Sentiment Analysis successful',
#   'ok': True,
#   'aggregate_sentiment': {'neg': 0.0,
#    'neu': 0.8552500000000001,
#    'pos': 0.14475,
#    'compound': 0.300875},
#   'sentiment_list': [{'neg': 0.0,
#     'neu': 0.625,
#     'pos': 0.375,
#     'compound': 0.4939,
#     'sentence': "Reliance extends Urban Ladder's presence at Smart Bazaar outlets."},
#    {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'Over Urban Ladder, now an omni-channel business, the focus is to provide more and more touch points to the customer, CFO Dinesh Taluja said.'},
#    {'neg': 0.0,
#     'neu': 0.796,
#     'pos': 0.204,
#     'compound': 0.7096,
#     'sentence': '"We are also expanding the category by putting it under many of the Smart Bazaars that we have launched so that it adds a new category into our Smart Bazaar portfolio.'},
#    {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'We\'ve also recently forayed into the institutional sales within the segment," he said.'}],
#   'sentiment': 'positive'},
#  {'app_version': 'v1.1',
#   'time_taken': 0.0012149810791015625,
#   'msg': 'Sentiment Analysis successful',
#   'ok': True,
#   'aggregate_sentiment': {'neg': 0.0,
#    'neu': 0.9818,
#    'pos': 0.0182,
#    'compound': 0.03558},
#   'sentiment_list': [{'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'Why Ambani and Jindal see future in debt-laden Future Group.'},
#    {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'Kishore Biyani, founder & CEO of Future Group, faces the decline of his business empire.'},
#    {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'Heavy debts, a series of acquisitions, and diversification into non-core ventures contributed to the downfall.'},
#    {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': "Now, Reliance Retail and Naveen Jindal's Jindal (India) are vying to acquire the remnants."},
#    {'neg': 0.0,
#     'neu': 0.909,
#     'pos': 0.091,
#     'compound': 0.1779,
#     'sentence': "Reliance Industries, in particular, stands to enhance its retail footprint and capitalize on India's growing organized retail sector."}],
#   'sentiment': 'neutral'},
#  {'app_version': 'v1.1',
#   'time_taken': 0.0009760856628417969,
#   'msg': 'Sentiment Analysis successful',
#   'ok': True,
#   'aggregate_sentiment': {'neg': 0.18,
#    'neu': 0.772,
#    'pos': 0.048,
#    'compound': -0.45855},
#   'sentiment_list': [{'neg': 0.209,
#     'neu': 0.791,
#     'pos': 0.0,
#     'compound': -0.4404,
#     'sentence': 'Weekly block deals exceed Rs 5,300 crore; HDFC Bank, RIL in spotlight.'},
#    {'neg': 0.151,
#     'neu': 0.753,
#     'pos': 0.096,
#     'compound': -0.4767,
#     'sentence': 'In the large cap segment, 15 companies witnessed significant block deals on the screen, which were worth Rs 3,533 crore, led by HDFC Bank with an 18 block count, totalling Rs 1,121 crore.'}],
#   'sentiment': 'negative'},
#  {'app_version': 'v1.1',
#   'time_taken': 0.0013556480407714844,
#   'msg': 'Sentiment Analysis successful',
#   'ok': True,
#   'aggregate_sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#   'sentiment_list': [{'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': "Reliance Industries Audio / Video Recording And Transcript Of Presentation On Unaudited Financial Results (Consolidated And Standalone) For .... Pursuant to Regulation 30(6) of the SEBI (Listing Obligations and Disclosure Requirements) Regulations, 2015, the audio / video recording and transcript of the presentation made on October 27, 2023, on Unaudited Financial Results (Consolidated and Standalone) of the Company for the quarter and half-year ended September 30, 2023, is available on the Company''s website."},
#    {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'The transcript is also attached.'},
#    {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'The presentation concluded at 9:06 p.m. (IST) on October 27, 2023.'}],
#   'sentiment': 'neutral'},
#  {'app_version': 'v1.1',
#   'time_taken': 0.0021669864654541016,
#   'msg': 'Sentiment Analysis successful',
#   'ok': True,
#   'aggregate_sentiment': {'neg': 0.06775,
#    'neu': 0.62775,
#    'pos': 0.3045,
#    'compound': 0.5536000000000001},
#   'sentiment_list': [{'neg': 0.0,
#     'neu': 0.755,
#     'pos': 0.245,
#     'compound': 0.3818,
#     'sentence': 'Revenue growth marks start of new upcycle at Reliance.'},
#    {'neg': 0.0,
#     'neu': 0.635,
#     'pos': 0.365,
#     'compound': 0.872,
#     'sentence': 'Reliance Industries reported strong Q2 growth across its energy, retail, and telecom divisions, with a 30% YoY rise in operating profit to ₹44,867 crore.'},
#    {'neg': 0.11,
#     'neu': 0.605,
#     'pos': 0.285,
#     'compound': 0.5994,
#     'sentence': "Robust performance in the oil-to-chemicals, exploration, and retail segments, along with a surge in Singapore gross refining margin, contributed to RIL's success."},
#    {'neg': 0.161,
#     'neu': 0.516,
#     'pos': 0.323,
#     'compound': 0.3612,
#     'sentence': "With RIL's improving financials and debt stabilization, investor concerns have eased."}],
#   'sentiment': 'positive'},
#  {'app_version': 'v1.1',
#   'time_taken': 0.0009737014770507812,
#   'msg': 'Sentiment Analysis successful',
#   'ok': True,
#   'aggregate_sentiment': {'neg': 0.07264245251582804,
#    'neu': 0.7597467510829723,
#    'pos': 0.16761079640119958,
#    'compound': 0.09910000000000001},
#   'sentiment_list': [{'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': "RIL Q2 Takeaways: How India's biggest conglomerate fared in September quarter."},
#    {'neg': 0.0,
#     'neu': 0.667,
#     'pos': 0.333,
#     'compound': 0.6705,
#     'sentence': 'Profit growth was led by operational and financial contributions from all business segments.'},
#    {'neg': 0.218,
#     'neu': 0.613,
#     'pos': 0.17,
#     'compound': -0.3732,
#     'sentence': 'The oil and gas segment delivered the most with robust growth and the dominant O2C business was hurt by a fall in crude oil prices'}],
#   'sentiment': 'neutral'},
#  {'app_version': 'v1.1',
#   'time_taken': 0.0007147789001464844,
#   'msg': 'Sentiment Analysis successful',
#   'ok': True,
#   'aggregate_sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#   'sentiment_list': [{'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'Reliance Industries Announcement under Regulation 30 (LODR)-Investor Presentation.'},
#    {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'Presentation made to analyst on Unaudited Financial Results (Consolidated and Standalone) for the quarter and half-year ended September 30, 2023'}],
#   'sentiment': 'neutral'},
#  {'app_version': 'v1.1',
#   'time_taken': 0.0011749267578125,
#   'msg': 'Sentiment Analysis successful',
#   'ok': True,
#   'aggregate_sentiment': {'neg': 0.0,
#    'neu': 0.9780000000000001,
#    'pos': 0.022000000000000002,
#    'compound': 0.13396666666666665},
#   'sentiment_list': [{'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'Reliance Industries Disclosure Dated August 28, 2023 Under Regulation 30 Of SEBI (Listing Obligations And Disclosure Requirements) Regulatio....'},
#    {'neg': 0.0,
#     'neu': 0.934,
#     'pos': 0.066,
#     'compound': 0.4019,
#     'sentence': 'In continuation to our disclosure dated August 28, 2023, we wish to inform you that Ms. Isha M. Ambani, Shri Akash M. Ambani and Shri Anant M. Ambani have assumed office as Non-executive Directors of the Company today i.e.'},
#    {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'October 27, 2023.'}],
#   'sentiment': 'neutral'},
#  {'app_version': 'v1.1',
#   'time_taken': 0.0021457672119140625,
#   'msg': 'Sentiment Analysis successful',
#   'ok': True,
#   'aggregate_sentiment': {'neg': 0.05202601300650325,
#    'neu': 0.7588794397198599,
#    'pos': 0.18909454727363684,
#    'compound': 0.5185},
#   'sentiment_list': [{'neg': 0.104,
#     'neu': 0.758,
#     'pos': 0.137,
#     'compound': 0.1779,
#     'sentence': 'Jio Platforms Q2 Results: Net profit rises 12% on-year to Rs 5,297 crore; costs, no rate hikes weigh.'},
#    {'neg': 0.0,
#     'neu': 0.759,
#     'pos': 0.241,
#     'compound': 0.8591,
#     'sentence': 'The Reliance Industries subsidiary posted a 10.7% increase in revenue from operations on-year at Rs 26,875 crore, led by a strong increase in subscriber base growth across mobility and homes and scale-up of digital platforms, the company said Friday'}],
#   'sentiment': 'positive'},
#  {'app_version': 'v1.1',
#   'time_taken': 0.0008261203765869141,
#   'msg': 'Sentiment Analysis successful',
#   'ok': True,
#   'aggregate_sentiment': {'neg': 0.0,
#    'neu': 0.9025000000000001,
#    'pos': 0.0975,
#    'compound': 0.2202},
#   'sentiment_list': [{'neg': 0.0,
#     'neu': 0.805,
#     'pos': 0.195,
#     'compound': 0.4404,
#     'sentence': 'Reliance Retail Q2 Results: Net profit rises 21% YoY to Rs 2,790 crore.'},
#    {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'Reliance Retail revenue from operations rose 19% to Rs 68,937 crore in the reporting quarter, compared with Rs 57,694 crore in the corresponding quarter of previous year.'}],
#   'sentiment': 'neutral'},
#  {'app_version': 'v1.1',
#   'time_taken': 0.0008270740509033203,
#   'msg': 'Sentiment Analysis successful',
#   'ok': True,
#   'aggregate_sentiment': {'neg': 0.08533333333333333,
#    'neu': 0.8496666666666667,
#    'pos': 0.065,
#    'compound': -0.0121},
#   'sentiment_list': [{'neg': 0.0,
#     'neu': 0.805,
#     'pos': 0.195,
#     'compound': 0.4404,
#     'sentence': 'Reliance Industries Q2 Results: Net profit rises 30% YoY to Rs 19,878 crore.'},
#    {'neg': 0.256,
#     'neu': 0.744,
#     'pos': 0.0,
#     'compound': -0.4767,
#     'sentence': "RIL's gross revenue rose 1.2% YoY to Rs 255,996 crore."},
#    {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': "During the quarter, the company's EBITDA margin rose 390 bps to 17.5%."}],
#   'sentiment': 'negative'},
#  {'app_version': 'v1.1',
#   'time_taken': 0.0006711483001708984,
#   'msg': 'Sentiment Analysis successful',
#   'ok': True,
#   'aggregate_sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#   'sentiment_list': [{'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'Reliance Industries Announcement under Regulation 30 (LODR)-Press Release / Media Release.'},
#    {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'Media Release - Consolidated and Standalone Unaudited Financial Results for the quarter and half year ended September 30, 2023.'}],
#   'sentiment': 'neutral'},
#  {'app_version': 'v1.1',
#   'time_taken': 0.0012497901916503906,
#   'msg': 'Sentiment Analysis successful',
#   'ok': True,
#   'aggregate_sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#   'sentiment_list': [{'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'Reliance Industries Consolidated And Standalone Unaudited Financial Results For The Quarter And Half-Year Ended September 30, 2023.'},
#    {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': "In continuation to our letter dated October 20, 2023 and pursuant to Regulation 33 and other applicable provisions of the SEBI (Listing Obligations and Disclosure Requirements) Regulations, 2015, we attach the Unaudited Financial Results (Consolidated and Standalone) for the quarter and half year ended September 30, 2023, along with Independent Auditor''s Review Report."}],
#   'sentiment': 'neutral'},
#  {'app_version': 'v1.1',
#   'time_taken': 0.0009458065032958984,
#   'msg': 'Sentiment Analysis successful',
#   'ok': True,
#   'aggregate_sentiment': {'neg': 0.09863378873708763,
#    'neu': 0.8550483172275908,
#    'pos': 0.046317894035321557,
#    'compound': -0.014999999999999994},
#   'sentiment_list': [{'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'Reliance Industries Compliances-Reg.'},
#    {'neg': 0.223,
#     'neu': 0.777,
#     'pos': 0.0,
#     'compound': -0.3182,
#     'sentence': '39 (3) - Details of Loss of Certificate / Duplicate Certificate.'},
#    {'neg': 0.073,
#     'neu': 0.789,
#     'pos': 0.139,
#     'compound': 0.2732,
#     'sentence': 'We enclose the information regarding loss of share certificate(s) received from the shareholder(s) of the Company on October 26, 2023 and October 27, 2023 aggregating to 11,411 shares.'}],
#   'sentiment': 'negative'},
#  {'app_version': 'v1.1',
#   'time_taken': 0.0007309913635253906,
#   'msg': 'Sentiment Analysis successful',
#   'ok': True,
#   'aggregate_sentiment': {'neg': 0.0,
#    'neu': 0.6805,
#    'pos': 0.3195,
#    'compound': 0.5831999999999999},
#   'sentiment_list': [{'neg': 0.0,
#     'neu': 0.592,
#     'pos': 0.408,
#     'compound': 0.7645,
#     'sentence': 'Share market update: Most active stocks of the day in terms of traded value.'},
#    {'neg': 0.0,
#     'neu': 0.769,
#     'pos': 0.231,
#     'compound': 0.4019,
#     'sentence': 'The NSE Nifty index closed 190.0 points up at 19047.25'}],
#   'sentiment': 'positive'},
#  {'app_version': 'v1.1',
#   'time_taken': 0.0018422603607177734,
#   'msg': 'Sentiment Analysis successful',
#   'ok': True,
#   'aggregate_sentiment': {'neg': 0.0,
#    'neu': 0.9698,
#    'pos': 0.030200000000000005,
#    'compound': 0.22505999999999998},
#   'sentiment_list': [{'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'Reliance Industries Shareholder Meeting / Postal Ballot-Outcome of Postal_Ballot.'},
#    {'neg': 0.0,
#     'neu': 0.934,
#     'pos': 0.066,
#     'compound': 0.4767,
#     'sentence': 'The Company had sought approval of the members of the Company for: (i) Appointment of Ms. Isha M. Ambani (DIN:06984175) as a Non-Executive Director of the Company; (ii) Appointment of Shri Akash M. Ambani (DIN:06984194) as a Non-Executive Director of the Company; and (iii) Appointment of Shri.'},
#    {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'Anant M. Ambani (DIN: 07945702) as a Non-Executive Director of the Company.'},
#    {'neg': 0.0,
#     'neu': 0.915,
#     'pos': 0.085,
#     'compound': 0.6486,
#     'sentence': "Details of voting results of the Postal Ballot, conducted through remote e-voting process, in respect of resolutions contained in the postal ballot notice dated September 25, 2023 is attached in the format prescribed under Regulation 44(3) of the Securities and Exchange Board of India (Listing Obligations and Disclosure Requirements) Regulations, 2015, together with the Scrutinizer''s Report on the e-voting."},
#    {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'The said resolutions have been passed with more than requisite majority on October 26, 2023 (the last date of e-voting)'}],
#   'sentiment': 'neutral'},
#  {'app_version': 'v1.1',
#   'time_taken': 0.0007746219635009766,
#   'msg': 'Sentiment Analysis successful',
#   'ok': True,
#   'aggregate_sentiment': {'neg': 0.0,
#    'neu': 0.6995,
#    'pos': 0.3005,
#    'compound': 0.5831999999999999},
#   'sentiment_list': [{'neg': 0.0,
#     'neu': 0.612,
#     'pos': 0.388,
#     'compound': 0.7645,
#     'sentence': 'Share market update: Most active stocks of the day in terms of total traded value.'},
#    {'neg': 0.0,
#     'neu': 0.787,
#     'pos': 0.213,
#     'compound': 0.4019,
#     'sentence': 'The NSE Nifty index was trading 174.6 points up at 19031.85'}],
#   'sentiment': 'positive'},
#  {'app_version': 'v1.1',
#   'time_taken': 0.0009851455688476562,
#   'msg': 'Sentiment Analysis successful',
#   'ok': True,
#   'aggregate_sentiment': {'neg': 0.043,
#    'neu': 0.7224999999999999,
#    'pos': 0.23450000000000001,
#    'compound': 0.47395000000000004},
#   'sentiment_list': [{'neg': 0.0,
#     'neu': 0.612,
#     'pos': 0.388,
#     'compound': 0.7456,
#     'sentence': "GIFT Nifty up 50 points; here's the trading setup for today's session."},
#    {'neg': 0.086,
#     'neu': 0.833,
#     'pos': 0.081,
#     'compound': 0.2023,
#     'sentence': 'The rupee continued its downward trend for the third consecutive session to close 8 paise lower at 83.25 against the US dollar on Thursday, dragged down by massive selling in equity markets and strengthening American currency overseas.'}],
#   'sentiment': 'positive'},
#  {'app_version': 'v1.1',
#   'time_taken': 0.0008299350738525391,
#   'msg': 'Sentiment Analysis successful',
#   'ok': True,
#   'aggregate_sentiment': {'neg': 0.0,
#    'neu': 0.9393333333333334,
#    'pos': 0.06066666666666667,
#    'compound': 0.1468},
#   'sentiment_list': [{'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': "Stocks in news: RIL, Maruti, Vodafone Idea, Cipla, Dr Reddy's."},
#    {'neg': 0.0,
#     'neu': 0.818,
#     'pos': 0.182,
#     'compound': 0.4404,
#     'sentence': 'Laxmi Organic reported net profit of Rs 10.7 crore for the quarter ended September.'},
#    {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'Revenue from operations stood at Rs 652 crore.'}],
#   'sentiment': 'neutral'},
#  {'app_version': 'v1.1',
#   'time_taken': 0.0008742809295654297,
#   'msg': 'Sentiment Analysis successful',
#   'ok': True,
#   'aggregate_sentiment': {'neg': 0.103,
#    'neu': 0.8420000000000001,
#    'pos': 0.055,
#    'compound': -0.014999999999999994},
#   'sentiment_list': [{'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'Reliance Industries Compliances-Reg.'},
#    {'neg': 0.223,
#     'neu': 0.777,
#     'pos': 0.0,
#     'compound': -0.3182,
#     'sentence': '39 (3) - Details of Loss of Certificate / Duplicate Certificate.'},
#    {'neg': 0.086,
#     'neu': 0.749,
#     'pos': 0.165,
#     'compound': 0.2732,
#     'sentence': 'We enclose the information regarding loss of share certificates for 2,407 shares received from the shareholders of the Company on October 25, 2023.'}],
#   'sentiment': 'negative'},
#  {'app_version': 'v1.1',
#   'time_taken': 0.0011830329895019531,
#   'msg': 'Sentiment Analysis successful',
#   'ok': True,
#   'aggregate_sentiment': {'neg': 0.0,
#    'neu': 0.6805,
#    'pos': 0.3195,
#    'compound': 0.5831999999999999},
#   'sentiment_list': [{'neg': 0.0,
#     'neu': 0.592,
#     'pos': 0.408,
#     'compound': 0.7645,
#     'sentence': 'Share market update: Most active stocks of the day in terms of traded value.'},
#    {'neg': 0.0,
#     'neu': 0.769,
#     'pos': 0.231,
#     'compound': 0.4019,
#     'sentence': 'The NSE Nifty index closed 264.9 points down at 18857.25'}],
#   'sentiment': 'positive'},
#  {'app_version': 'v1.1',
#   'time_taken': 0.0012104511260986328,
#   'msg': 'Sentiment Analysis successful',
#   'ok': True,
#   'aggregate_sentiment': {'neg': 0.041,
#    'neu': 0.8476666666666667,
#    'pos': 0.11133333333333334,
#    'compound': 0.29886666666666667},
#   'sentiment_list': [{'neg': 0.123,
#     'neu': 0.877,
#     'pos': 0.0,
#     'compound': -0.2732,
#     'sentence': 'India can reduce fossil fuel dependence, cut import bills by $29 bn through biogas adoption: Report.'},
#    {'neg': 0.0,
#     'neu': 0.833,
#     'pos': 0.167,
#     'compound': 0.5574,
#     'sentence': 'According to the report\'s author Purva Jain, an energy analyst at IEEFA, "Biogas has the potential to replace natural gas and other high-emission fossil fuels.'},
#    {'neg': 0.0,
#     'neu': 0.833,
#     'pos': 0.167,
#     'compound': 0.6124,
#     'sentence': 'By eliminating carbon dioxide (CO2) and impurities like hydrogen sulfide, its methane content can be upgraded to 90 per cent, making it calorifically equivalent to natural gas.'}],
#   'sentiment': 'neutral'},
#  {'app_version': 'v1.1',
#   'time_taken': 0.0010974407196044922,
#   'msg': 'Sentiment Analysis successful',
#   'ok': True,
#   'aggregate_sentiment': {'neg': 0.12253063265816455,
#    'neu': 0.7271817954488623,
#    'pos': 0.15028757189297323,
#    'compound': -0.109675},
#   'sentiment_list': [{'neg': 0.0,
#     'neu': 0.649,
#     'pos': 0.351,
#     'compound': 0.4019,
#     'sentence': 'Nifty down 1,300 points from peak.'},
#    {'neg': 0.333,
#     'neu': 0.49,
#     'pos': 0.176,
#     'compound': -0.3818,
#     'sentence': 'Adani stocks, HDFC Bank among top losers.'},
#    {'neg': 0.157,
#     'neu': 0.769,
#     'pos': 0.074,
#     'compound': -0.4588,
#     'sentence': 'Since September 15, when Nifty hit lifetime intra-day peak of 20,222.45 and Sensex 67,927.23, Tech Mahindra and Wipro have been the biggest losers among bluechips with a 14% loss during the period.'},
#    {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'Peer Infosys is down around 10% since then.'}],
#   'sentiment': 'negative'},
#  {'app_version': 'v1.1',
#   'time_taken': 0.0011188983917236328,
#   'msg': 'Sentiment Analysis successful',
#   'ok': True,
#   'aggregate_sentiment': {'neg': 0.0,
#    'neu': 0.777,
#    'pos': 0.223,
#    'compound': 0.4846},
#   'sentiment_list': [{'neg': 0.0,
#     'neu': 0.559,
#     'pos': 0.441,
#     'compound': 0.7269,
#     'sentence': 'RIL Q2 Preview: A mixed bag seen with solid profit growth & subdued revenues.'},
#    {'neg': 0.0,
#     'neu': 0.772,
#     'pos': 0.228,
#     'compound': 0.7269,
#     'sentence': 'RIL Q2 Preview: Net profit for the September quarter is likely to show a solid growth of around 25% year-on-year, according to an average estimate of three brokerages.'},
#    {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'Revenue from operations, however, is likely to grow marginally (2-3%) or even decline by 2% to 2.25 lakh crore.'}],
#   'sentiment': 'positive'},
#  {'app_version': 'v1.1',
#   'time_taken': 0.0007379055023193359,
#   'msg': 'Sentiment Analysis successful',
#   'ok': True,
#   'aggregate_sentiment': {'neg': 0.0,
#    'neu': 0.6995,
#    'pos': 0.3005,
#    'compound': 0.5831999999999999},
#   'sentiment_list': [{'neg': 0.0,
#     'neu': 0.612,
#     'pos': 0.388,
#     'compound': 0.7645,
#     'sentence': 'Share market update: Most active stocks of the day in terms of total traded value.'},
#    {'neg': 0.0,
#     'neu': 0.787,
#     'pos': 0.213,
#     'compound': 0.4019,
#     'sentence': 'The NSE Nifty index was trading 260.35 points down at 18861.8'}],
#   'sentiment': 'positive'},
#  {'app_version': 'v1.1',
#   'time_taken': 0.0007808208465576172,
#   'msg': 'Sentiment Analysis successful',
#   'ok': True,
#   'aggregate_sentiment': {'neg': 0.0,
#    'neu': 0.942,
#    'pos': 0.058,
#    'compound': 0.2202},
#   'sentiment_list': [{'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'More independent directors get chair at high table.'},
#    {'neg': 0.0,
#     'neu': 0.884,
#     'pos': 0.116,
#     'compound': 0.4404,
#     'sentence': 'Several large progressive-minded companies following good governance practices are also looking to send a message to investors about a transparent culture and mindset, experts said.'}],
#   'sentiment': 'neutral'},
#  {'app_version': 'v1.1',
#   'time_taken': 0.0008716583251953125,
#   'msg': 'Sentiment Analysis successful',
#   'ok': True,
#   'aggregate_sentiment': {'neg': 0.10233333333333333,
#    'neu': 0.871,
#    'pos': 0.02666666666666667,
#    'compound': -0.11466666666666665},
#   'sentiment_list': [{'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'Reliance Industries Compliances-Reg.'},
#    {'neg': 0.223,
#     'neu': 0.777,
#     'pos': 0.0,
#     'compound': -0.3182,
#     'sentence': '39 (3) - Details of Loss of Certificate / Duplicate Certificate.'},
#    {'neg': 0.084,
#     'neu': 0.836,
#     'pos': 0.08,
#     'compound': -0.0258,
#     'sentence': 'We enclose the details of Letter(s) of Confirmation issued by the Company to its shareholders in lieu of share certificates reported as lost by them.'}],
#   'sentiment': 'negative'},
#  {'app_version': 'v1.1',
#   'time_taken': 0.0013260841369628906,
#   'msg': 'Sentiment Analysis successful',
#   'ok': True,
#   'aggregate_sentiment': {'neg': 0.0,
#    'neu': 0.921,
#    'pos': 0.079,
#    'compound': 0.280075},
#   'sentiment_list': [{'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'Jio ties up with Plume to offer AI-based services to JioFiber, JioAirFiber users.'},
#    {'neg': 0.0,
#     'neu': 0.903,
#     'pos': 0.097,
#     'compound': 0.4019,
#     'sentence': 'Reliance Jio, the telecom unit of Reliance Industries, has partnered with Plume to offer smart home and small business services to 200 million premises in India.'},
#    {'neg': 0.0,
#     'neu': 0.781,
#     'pos': 0.219,
#     'compound': 0.7184,
#     'sentence': 'The partnership will enable Jio to provide advanced and secure in-home digital services, including whole-home adaptive WiFi, device performance optimization, cyberthreat protection, parental controls, and WiFi motion sensing.'},
#    {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'Jio aims to enhance its connected home services and customer experience through this collaboration.'}],
#   'sentiment': 'neutral'},
#  {'app_version': 'v1.1',
#   'time_taken': 0.0012094974517822266,
#   'msg': 'Sentiment Analysis successful',
#   'ok': True,
#   'aggregate_sentiment': {'neg': 0.0,
#    'neu': 0.91325,
#    'pos': 0.08675,
#    'compound': 0.148},
#   'sentiment_list': [{'neg': 0.0,
#     'neu': 0.82,
#     'pos': 0.18,
#     'compound': 0.296,
#     'sentence': 'Team Ambani bought 6.1 crore shares of Jio Financial after listing.'},
#    {'neg': 0.0,
#     'neu': 0.833,
#     'pos': 0.167,
#     'compound': 0.296,
#     'sentence': 'September quarter shareholding data shows the promoters have bought 6.1 crore shares.'},
#    {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'In the meantime, mutual funds have decreased their ownership from 6.27% to 4.71%.'},
#    {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'FIIs too have reduced holding to 21.58% from 26.4% at the time of listing.'}],
#   'sentiment': 'neutral'},
#  {'app_version': 'v1.1',
#   'time_taken': 0.0012180805206298828,
#   'msg': 'Sentiment Analysis successful',
#   'ok': True,
#   'aggregate_sentiment': {'neg': 0.03475,
#    'neu': 0.9115,
#    'pos': 0.05375,
#    'compound': 0.0943},
#   'sentiment_list': [{'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'OCS Services starts O&M services for FPSO KG-D6 Ruby.'},
#    {'neg': 0.139,
#     'neu': 0.861,
#     'pos': 0.0,
#     'compound': -0.4404,
#     'sentence': 'The FPSO is currently deployed in the MJ field in the KG-D6 block, off the east coast of India.'},
#    {'neg': 0.0,
#     'neu': 0.785,
#     'pos': 0.215,
#     'compound': 0.8176,
#     'sentence': 'Raju Shete, founder of OCS Services, said, "We are honoured to be part of this prestigious project of national importance and to contribute our expertise in delivering high standards for safety and environmental protection.'},
#    {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'We look forward to our continued services to Reliance".'}],
#   'sentiment': 'neutral'},
#  {'app_version': 'v1.1',
#   'time_taken': 0.0007052421569824219,
#   'msg': 'Sentiment Analysis successful',
#   'ok': True,
#   'aggregate_sentiment': {'neg': 0.0,
#    'neu': 0.6805,
#    'pos': 0.3195,
#    'compound': 0.5831999999999999},
#   'sentiment_list': [{'neg': 0.0,
#     'neu': 0.592,
#     'pos': 0.408,
#     'compound': 0.7645,
#     'sentence': 'Share market update: Most active stocks of the day in terms of traded value.'},
#    {'neg': 0.0,
#     'neu': 0.769,
#     'pos': 0.231,
#     'compound': 0.4019,
#     'sentence': 'The NSE Nifty index closed 159.6 points down at 19122.15'}],
#   'sentiment': 'positive'},
#  {'app_version': 'v1.1',
#   'time_taken': 0.0018429756164550781,
#   'msg': 'Sentiment Analysis successful',
#   'ok': True,
#   'aggregate_sentiment': {'neg': 0.0,
#    'neu': 0.9503333333333334,
#    'pos': 0.04966666666666667,
#    'compound': 0.20550000000000002},
#   'sentiment_list': [{'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'These largecaps have ‘strong buy’ & ‘buy’ recos and upside potential of more than 20%.'},
#    {'neg': 0.0,
#     'neu': 0.928,
#     'pos': 0.072,
#     'compound': 0.3612,
#     'sentence': 'While the correction has been going on in the market since the middle of July, it is only on days like Monday where everyone on the street feels that equity markets are correcting.'},
#    {'neg': 0.0,
#     'neu': 0.873,
#     'pos': 0.127,
#     'compound': 0.3612,
#     'sentence': 'It is only a matter of time that the concept of relative valuation will come into play and large caps will get more attention from the market.'},
#    {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'Stocks from different sectors are making to the list, this week, stocks from Oil refining and marketing, private banks, insurance, auto ancillary and fertilizer space.'},
#    {'neg': 0.0,
#     'neu': 0.901,
#     'pos': 0.099,
#     'compound': 0.5106,
#     'sentence': 'ET screener powered by Refinitiv’s Stock Report Plus lists down quality stocks with high upside potential over the next 12 months, having an average recommendation rating of “buy” or "strong buy".'},
#    {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0,
#     'sentence': 'The screener applies different algorithms for all BSE and NSE stocks.'}],
#   'sentiment': 'neutral'}]

# %%
#  add to df from responses
df['sentiment'] = [x['sentiment'] for x in responses]
# df['confidence'] = [x['confidence'] for x in responses]
df['positive'] = [x['aggregate_sentiment']['pos'] for x in responses]
df['negative'] = [x['aggregate_sentiment']['neg'] for x in responses]
df['neutral'] = [x['aggregate_sentiment']['neu'] for x in responses]

# %%
df.head()
# Out:
#                                                title  \
# 0  Share market update: Most active stocks of the...
# 1  RIL shares jump 2% post Q2 earnings despite Mo...
# 2  Buy Reliance Industries, target price Rs 2760:...
# 3  Hot Stocks: Brokerage view on RIL, Cipla, Maru...
# 4  Stocks in news: RIL, Adani Green, IDFC First B...
#
#                        date  \
# 0  30 Oct 2023, 11:25AM IST
# 1  30 Oct 2023, 10:16AM IST
# 2  30 Oct 2023, 09:35AM IST
# 3  30 Oct 2023, 09:26AM IST
# 4  30 Oct 2023, 07:00AM IST
#
#                                                 info sentiment  positive  \
# 0  The NSE Nifty index was trading 49.5 points up...  positive    0.3005
# 1  Brokerages reviewed Reliance Industries stock ...   neutral    0.0392
# 2  Reliance Industries Ltd. key Products/Revenue ...   neutral    0.0000
# 3  The September quarter results were in line wit...   neutral    0.0000
# 4  IDFC First Bank reported consolidated net prof...   neutral    0.0635
#
#    negative  neutral
# 0       0.0   0.6995
# 1       0.0   0.9608
# 2       0.0   1.0000
# 3       0.0   1.0000
# 4       0.0   0.9365

# %%
df.tail()
# Out:
#                                                 title  \
# 35  Jio ties up with Plume to offer AI-based servi...
# 36  Team Ambani bought 6.1 crore shares of Jio Fin...
# 37  OCS Services starts O&M services for FPSO KG-D...
# 38  Share market update: Most active stocks of the...
# 39  These largecaps have ‘strong buy’ & ‘buy’ reco...
#
#                         date  \
# 35  25 Oct 2023, 07:15PM IST
# 36  25 Oct 2023, 06:10PM IST
# 37  25 Oct 2023, 05:06PM IST
# 38  25 Oct 2023, 04:05PM IST
# 39  25 Oct 2023, 11:45AM IST
#
#                                                  info sentiment  positive  \
# 35  Reliance Jio, the telecom unit of Reliance Ind...   neutral  0.079000
# 36  September quarter shareholding data shows the ...   neutral  0.086750
# 37  The FPSO is currently deployed in the MJ field...   neutral  0.053750
# 38  The NSE Nifty index closed 159.6 points down a...  positive  0.319500
# 39  While the correction has been going on in the ...   neutral  0.049667
#
#     negative   neutral
# 35   0.00000  0.921000
# 36   0.00000  0.913250
# 37   0.03475  0.911500
# 38   0.00000  0.680500
# 39   0.00000  0.950333

# %%
df.columns
# Out:
# Index(['title', 'date', 'info'], dtype='object')

# %%
df.to_csv('article_analysis.csv', index=False)

# %%
import requests
import pandas as pd

# replace YOUR_API_KEY with your actual API key
API_Key="7TMMXLDM3287Z2T4"
url = f"https://www.alphavantage.co/query?function=TIME_SERIES_DAILY_ADJUSTED&symbol=RIL.BSE&apikey={API_Key}"
response = requests.get(url)

# convert response to dataframe
data = response.json()
print(data)
# ndf = pd.DataFrame.from_dict(data, orient='index')
# ndf.index = pd.to_datetime(ndf.index)
# ndf = ndf.loc['2023-10-25':'2023-10-30']
# Out:
# {'Information': 'Thank you for using Alpha Vantage! This is a premium endpoint. You may subscribe to any of the premium plans at https://www.alphavantage.co/premium/ to instantly unlock all premium endpoints'}
